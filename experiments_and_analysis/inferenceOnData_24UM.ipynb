# %% [markdown]
# ## set up

# %%
#set up
import torch, detectron2
from detectron2.utils.logger import setup_logger
import numpy as np
import os, json, cv2, random
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from matplotlib import pyplot as plt
from detectron2.utils.visualizer import ColorMode
import pandas as pd

# %matplotlib inline

# %%
cfg = get_cfg()

#using mask-rcnn config, setting weight to model 0001399.pth
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"))
cfg.MODEL.DEVICE = 'cpu'
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1

#maize setaria joint model
cfg.MODEL.WEIGHTS = "/work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/training/output/model_final.pth"
#set confidence threshold
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.82
predictor = DefaultPredictor(cfg)

# %% [markdown]
# ## functions for running analysis

# %%
#functions for running analysis

#these parameters can be changed depending on exp
scan_x_dim=1008 #input scan dimensions
scan_y_dim=672
scan_overlap_length=266 #overlap amount between scans

def inferenceOnData(files,planting_date,genotype,treatment,savePath):
        def buildInferenceTable(image_id, outputs):
            #generate temp dataframe for individual image
            df = pd.DataFrame(columns=['image_id', 'planting_date', 'genotype', 'treatment', 'pistil_area', 'pistil_circularity', 'bbox', 'segm', 'confidence', 'center_x', 'center_y', 'perimeter_intersect', 'possible_overlap'])
            if len(outputs["instances"])==0:
                print("No detections for image")
                return df
            for i in range(0,len(outputs["instances"])):
                pred = outputs["instances"][i]
                pmask = pred.pred_masks.numpy().astype(int)[0]
                df.loc[len(df.index)] = [str(image_id),
                                         str(planting_date),
                                         str(genotype), 
                                         str(treatment),
                                         calcAreaOfBinaryMask(pmask),
                                         calcCircularity(pmask),
                                         pred.pred_boxes.tensor.numpy(),
                                         str(binaryMaskToRLE(pmask.astype(np.uint8))),
                                         pred.scores.numpy()[0],
                                         getDetectionCenter(pmask)[0],
                                         getDetectionCenter(pmask)[1],
                                         checkPerimeterIntersect(pmask),
                                         checkScanOverlap(pmask)]
            return df

        all_dfs = pd.DataFrame()
        for f in files:
            im = cv2.imread(f)
            #run inference
            outputs = predictor(im)
            #send output to analysis
            all_dfs = pd.concat([all_dfs, buildInferenceTable(f, outputs)])
            print("Progress:", files.index(f), "/", len(files), "Running inference on", f)
            #print(all_dfs) for debug
            
        #once all inference is done, extract plant_id, scan_position, and scan_angle from image name
        all_dfs["position_y"] = all_dfs['image_id'].str.find('~')
        all_dfs["scan_position"] = all_dfs.apply(lambda row: row['image_id'][row["position_y"] + 1 : row["position_y"] + 3], axis=1)
        all_dfs["scan_angle"] = all_dfs.apply(lambda row: row['image_id'][row["position_y"] + 9 : row["position_y"] + 11], axis=1)
        all_dfs["plant_id"] = all_dfs.apply(lambda row: row['image_id'][row["position_y"] - 6 : row["position_y"] ], axis=1)
        all_dfs = all_dfs.drop('position_y', axis=1)
        all_dfs["total_scans_for_sample"] = all_dfs.groupby("plant_id")["scan_position"].transform('max')
        all_dfs.loc[all_dfs["scan_position"] == "00", "possible_overlap"] = False #if the scan position is 0 (bottom), set bottom overlap to false. (The first scan cannot have overlap there)
        
        #correct y position for each detection to account for scan overlap
        all_dfs["center_y"] = scan_y_dim - all_dfs["center_y"] #flip the center_y values so it is going from bottom to top (px 0 is at bottom and 672 is at top of scan)
        all_dfs["y_pos_all_overlapped"] = ((all_dfs["scan_position"].astype(int)+1) * all_dfs["center_y"]) - scan_overlap_length #multiply scan y position by detection y position. Subtract overlap amount for correction.
        all_dfs.loc[all_dfs["scan_position"] == "00", "y_pos_all_overlapped"]  = all_dfs[all_dfs["scan_position"] == "00"]["y_pos_all_overlapped"] + scan_overlap_length
        all_dfs["y_pos_all_overlapped_len_standardized"] = all_dfs["y_pos_all_overlapped"].astype(int) / ((all_dfs["total_scans_for_sample"].astype(int)+1)*scan_y_dim) #divide the position by the sample length

        #save final unfiltered dataframe
        all_dfs.to_csv(savePath + ".csv")
        
        #filter and save filtered dataframe
        all_dfs=all_dfs[all_dfs.pistil_circularity<=1]
        all_dfs=all_dfs[all_dfs["possible_overlap"]==False]
        all_dfs.to_csv(savePath + "_filtered.csv")
        
        return all_dfs

# %%
from pycocotools import mask

#assuming mask is [0,1] format
def calcAreaOfBinaryMask(pmask):
    return np.sum(pmask)

def calcPerimeterofBinaryMask(pmask):
    contours, _ = cv2.findContours(pmask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    perimeter = cv2.arcLength(contours[0], True)
    return perimeter
    
def calcCircularity(pmask):
    pmask = pmask.astype(np.uint8)
    perimeter = calcPerimeterofBinaryMask(pmask)
    area = calcAreaOfBinaryMask(pmask)
    circularity = ((4 * np.pi * area)) / (perimeter * perimeter)
    return circularity

def binaryMaskToRLE(pmask):
    return mask.encode(np.asfortranarray(pmask))

#does the pistil intersect with the perimeter of the image?
def checkPerimeterIntersect(pmask):
    pmask = pmask.astype(np.uint8)
    top_edge = np.any(pmask[0, :] > 0)
    bottom_edge = np.any(pmask[-1, :] > 0)
    left_edge = np.any(pmask[:, 0] > 0)
    right_edge = np.any(pmask[:, -1] > 0)
    intersects = top_edge or bottom_edge or left_edge or right_edge
    return intersects

#is the pistil in an overlapping part of the scan? Flag so it doesn't get counted twice.
#all images are 1008x672 resolution
def checkScanOverlap(pmask):
    y_dimension = scan_y_dim #change if using different dimension images
    bottom_overlap_region = scan_y_dim - scan_overlap_length #y coords flipped in this axis
    y_center = getDetectionCenter(pmask)[1]
    return y_center > bottom_overlap_region

def getDetectionCenter(pmask):
    pmask = pmask.astype(np.uint8)
    y1,y2,x1,x2 = get_bounding_box(pmask)
    y_center = (y1+y2)/2
    x_center = (x1+x2)/2
    return x_center, y_center

# %%
#decode RLE mask to binary mask, crop, display all masks
import ast
#mask.decode(ast.literal_eval(finalDf.segm[0]))

def get_bounding_box(pmask):
    # Get the rows and columns where the mask is non-zero
    rows = np.any(pmask, axis=1)
    cols = np.any(pmask, axis=0)
    # Get the bounding box
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

# %% [markdown]
# ## run inference on individual datasets

# %%
#specify dataset (lateusing 21UM data)

planting_date="late_planting" #early or late
genotype="tb1gt1ra3_het"#"tb1ra3""gt1-P_test"
treatment="no_treatment" #or defoliated
directory="/work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/experiments/maize_24UM/data/" + planting_date + "/" + genotype #+ "/"+ treatment
print(directory)
#print(planting_date, genotype, treatment)
all_items = os.listdir(directory)
print("Total images, all angles:", len(all_items))
#filter images for angle 08
files08 = [os.path.join(directory, item) for item in all_items if item.endswith('08.jpg') and os.path.isfile(os.path.join(directory, item))]
print("Images angle 08:", len(files08))
# Out:
# /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/experiments/maize_24UM/data/late_planting/tb1gt1ra3_
# 8     [[579.23956, 314.43683, 610.6886, 385.7729]]
# 10     [[600.7181, 337.95016, 628.1644, 387.1865]]
# 11    [[531.3157, 0.20422576, 567.5118, 70.04956]]
# 1     [[478.83173, 143.52158, 516.179, 230.67392]]
# 2    [[517.32605, 171.50964, 551.6142, 245.35947]]
# 4    [[469.8902, 275.60107, 508.50366, 339.85974]]
# 5      [[534.003, 200.8099, 564.67883, 252.45457]]
# 6    [[489.74832, 262.63412, 535.7839, 322.48215]]
# 7   [[450.92987, 172.11205, 486.52097, 233.83992]]
# 8         [[475.33447, 0.0, 525.85187, 43.329742]]
# 0    [[518.3982, 333.04514, 557.19275, 405.09305]]
#
#                                                  segm  confidence  center_x  \
# 0   {'size': [672, 1008], 'counts': b'\\`^<8`d0=H7...    0.988814     628.0
# 1   {'size': [672, 1008], 'counts': b'\\jV==^d06K5...    0.984959     665.5
# 2   {'size': [672, 1008], 'counts': b'SYm:e0Wd0;G6...    0.982529     549.0
# 3   {'size': [672, 1008], 'counts': b'Pni9=_d08I6K...    0.981701     495.5
# 4   {'size': [672, 1008], 'counts': b'c\\T:e0Xd0<F...    0.953728     513.5
# 5   {'size': [672, 1008], 'counts': b'Zda;k0lc0?E6...    0.950301     585.0
# 6   {'size': [672, 1008], 'counts': b'feb:>`d04L2N...    0.918198     531.5
# 7   {'size': [672, 1008], 'counts': b'Q\\h9l0Td03M...    0.916525     496.0
# 0   {'size': [672, 1008], 'counts': b'Tkm=7bd0`0D8...    0.991102     696.0
# 3   {'size': [672, 1008], 'counts': b'QPP<l0Pd06K4...    0.975316     604.5
# 5   {'size': [672, 1008], 'counts': b'TSg9;`d0:I5J...    0.973913     492.0
# 7   {'size': [672, 1008], 'counts': b'Uk^:o0nc06G8...    0.971430     529.5
# 10  {'size': [672, 1008], 'counts': b'S_l:?`d03M5L...    0.924380     550.0
# 0   {'size': [672, 1008], 'counts': b'Qc_:a0\\d06K...    0.990902     529.5
# 2   {'size': [672, 1008], 'counts': b'ghn;f0Sd0>F8...    0.989689     603.0
# 3   {'size': [672, 1008], 'counts': b'kXT:4gd0=D8I...    0.988688     513.5
# 5   {'size': [672, 1008], 'counts': b'Sla9g0Vd09H7...    0.987639     490.0
# 7   {'size': [672, 1008], 'counts': b'afT=>^d06J5L...    0.986667     658.5
# 9   {'size': [672, 1008], 'counts': b'dio:?]d08J6J...    0.979829     556.0
# 10  {'size': [672, 1008], 'counts': b'cnU;`0]d06J5...    0.977938     564.5
# 11  {'size': [672, 1008], 'counts': b'Tmk9c0[d05L3...    0.976205     498.5
# 12  {'size': [672, 1008], 'counts': b'_gg<d0Wd09F8...    0.973691     634.5
# 17  {'size': [672, 1008], 'counts': b'Tdk;f0Yd03N3...    0.909100     592.0
# 0   {'size': [672, 1008], 'counts': b'[VS:7ed08G7J...    0.993522     510.5
# 5   {'size': [672, 1008], 'counts': b'mTR=;bd05L3L...    0.983680     653.5
# 6   {'size': [672, 1008], 'counts': b'bhT<8Yd0k0@8...    0.981025     607.0
# 7   {'size': [672, 1008], 'counts': b'PZY;:cd0:F7I...    0.978627     567.0
# 9   {'size': [672, 1008], 'counts': b'\\d^<3dd0?E6...    0.977320     622.0
# 10  {'size': [672, 1008], 'counts': b'RXm:?^d0;F6J...    0.974688     549.5
# 12  {'size': [672, 1008], 'counts': b'gfc<6dd09G7J...    0.973226     632.0
# 13  {'size': [672, 1008], 'counts': b'\\n`:=`d0:Gb...    0.969863     531.0
# 14  {'size': [672, 1008], 'counts': b'f_j95hd08I7J...    0.967218     501.5
# 15  {'size': [672, 1008], 'counts': b'\\b[;d0Ud0b0...    0.965795     568.5
# 0   {'size': [672, 1008], 'counts': b'V^\\:5\\d0f0...    0.991202     527.0
# 2   {'size': [672, 1008], 'counts': b'^Wa98cd0>D5L...    0.983061     482.5
# 3   {'size': [672, 1008], 'counts': b'bdP:;[d0=H7J...    0.981118     506.0
# 5   {'size': [672, 1008], 'counts': b']iQ:e0lc0c0H...    0.976269     506.5
# 6   {'size': [672, 1008], 'counts': b'Xfj:o0nc05L4...    0.976220     544.0
# 8   {'size': [672, 1008], 'counts': b'Yol;<^d0;H5I...    0.956217     594.5
# 10  {'size': [672, 1008], 'counts': b'VhZ<b0Zd06M3...    0.918714     614.0
# 11  {'size': [672, 1008], 'counts': b'eTm:;ad0:G8I...    0.898385     549.0
# 1   {'size': [672, 1008], 'counts': b'eUk9f0Xd07I6...    0.979688     497.5
# 2   {'size': [672, 1008], 'counts': b'[Td:?\\d0>D9...    0.966135     533.0
# 4   {'size': [672, 1008], 'counts': b']\\e99ad0<H5...    0.959900     488.5
# 5   {'size': [672, 1008], 'counts': b'RZo:;ad09H6J...    0.939178     549.0
# 6   {'size': [672, 1008], 'counts': b'cTS:7dd0;I4L...    0.938524     513.5
# 7   {'size': [672, 1008], 'counts': b'kTX9b0[d08I5...    0.921188     467.5
# 8   {'size': [672, 1008], 'counts': b']\\h9;dd04L3...    0.886308     500.5
# 0   {'size': [672, 1008], 'counts': b'bnd:h0Rd09H6...    0.993343     537.0
#
#     center_y  perimeter_intersect  possible_overlap scan_position scan_angle  \
# 0      498.5                False             False            00         08
# 1      488.5                False             False            00         08
# 2      495.5                False             False            00         08
# 3      403.5                False             False            00         08
# 4      426.0                False             False            00         08
# 5      507.0                False             False            00         08
# 6      623.5                False             False            00         08
# 7      639.0                 True             False            00         08
# 0      415.0                False             False            01         08
# 3      569.5                False             False            01         08
# 5      631.5                False             False            01         08
# 7      503.0                False             False            01         08
# 10     650.5                 True             False            01         08
# 0      407.0                False             False            02         08
# 2      471.5                False             False            02         08
# 3      567.5                False             False            02         08
# 5      569.5                False             False            02         08
# 7      632.0                False             False            02         08
# 9      608.5                False             False            02         08
# 10     354.0                False             False            02         08
# 11     392.5                False             False            02         08
# 12     464.5                False             False            02         08
# 17     341.5                False             False            02         08
# 0      333.0                False             False            03         08
# 5      559.5                False             False            03         08
# 6      402.5                False             False            03         08
# 7      280.0                False             False            03         08
# 9      382.5                False             False            03         08
# 10     528.0                False             False            03         08
# 12     580.0                False             False            03         08
# 13     348.0                False             False            03         08
# 14     503.0                False             False            03         08
# 15     646.5                 True             False            03         08
# 0      280.5                False             False            04         08
# 2      580.0                False             False            04         08
# 3      266.5                False             False            04         08
# 5      431.0                False             False            04         08
# 6      453.5                False             False            04         08
# 8      319.0                False             False            04         08
# 10     309.0                False             False            04         08
# 11     637.0                False             False            04         08
# 1      484.0                False             False            05         08
# 2      463.5                False             False            05         08
# 4      362.5                False             False            05         08
# 5      445.0                False             False            05         08
# 6      378.0                False             False            05         08
# 7      468.5                False             False            05         08
# 8      651.0                 True             False            05         08
# 0      302.0                False             False            06         08
#
#    plant_id total_scans_for_sample  y_pos_all_overlapped  \
# 0    _281-8                     06                 498.5
# 1    _281-8                     06                 488.5
# 2    _281-8                     06                 495.5
# 3    _281-8                     06                 403.5
# 4    _281-8                     06                 426.0
# 5    _281-8                     06                 507.0
# 6    _281-8                     06                 623.5
# 7    _281-8                     06                 639.0
# 0    _281-8                     06                 564.0
# 3    _281-8                     06                 873.0
# 5    _281-8                     06                 997.0
# 7    _281-8                     06                 740.0
# 10   _281-8                     06                1035.0
# 0    _281-8                     06                 955.0
# 2    _281-8                     06                1148.5
# 3    _281-8                     06                1436.5
# 5    _281-8                     06                1442.5
# 7    _281-8                     06                1630.0
# 9    _281-8                     06                1559.5
# 10   _281-8                     06                 796.0
# 11   _281-8                     06                 911.5
# 12   _281-8                     06                1127.5
# 17   _281-8                     06                 758.5
# 0    _281-8                     06                1066.0
# 5    _281-8                     06                1972.0
# 6    _281-8                     06                1344.0
# 7    _281-8                     06                 854.0
# 9    _281-8                     06                1264.0
# 10   _281-8                     06                1846.0
# 12   _281-8                     06                2054.0
# 13   _281-8                     06                1126.0
# 14   _281-8                     06                1746.0
# 15   _281-8                     06                2320.0
# 0    _281-8                     06                1136.5
# 2    _281-8                     06                2634.0
# 3    _281-8                     06                1066.5
# 5    _281-8                     06                1889.0
# 6    _281-8                     06                2001.5
# 8    _281-8                     06                1329.0
# 10   _281-8                     06                1279.0
# 11   _281-8                     06                2919.0
# 1    _281-8                     06                2638.0
# 2    _281-8                     06                2515.0
# 4    _281-8                     06                1909.0
# 5    _281-8                     06                2404.0
# 6    _281-8                     06                2002.0
# 7    _281-8                     06                2545.0
# 8    _281-8                     06                3640.0
# 0    _281-8                     06                1848.0
#
#     y_pos_all_overlapped_len_standardized
# 0                                0.105867
# 1                                0.103741
# 2                                0.105230
# 3                                0.085672
# 4                                0.090561
# 5                                0.107781
# 6                                0.132440
# 7                                0.135842
# 0                                0.119898
# 3                                0.185587
# 5                                0.211947
# 7                                0.157313
# 10                               0.220026
# 0                                0.203019
# 2                                0.244048
# 3                                0.305272
# 5                                0.306548
# 7                                0.346514
# 9                                0.331420
# 10                               0.169218
# 11                               0.193665
# 12                               0.239583
# 17                               0.161139
# 0                                0.226616
# 5                                0.419218
# 6                                0.285714
# 7                                0.181548
# 9                                0.268707
# 10                               0.392432
# 12                               0.436650
# 13                               0.239371
# 14                               0.371173
# 15                               0.493197
# 0                                0.241497
# 2                                0.559949
# 3                                0.226616
# 5                                0.401573
# 6                                0.425383
# 8                                0.282526
# 10                               0.271896
# 11                               0.620536
# 1                                0.560799
# 2                                0.534651
# 4                                0.405825
# 5                                0.511054
# 6                                0.425595
# 7                                0.541029
# 8                                0.773810
# 0                                0.392857

# %% [markdown]
# ## run inference on all datasets (all groups)

# %%
planting_dates=["early_planting","late_planting"]
genotypes=["B73", "gt1B73", "ra3B73", "gt1ra3B73"]
treatments=["no_treatment","defoliated"]

for p in planting_dates:
    for g in genotypes:
        for t in treatments:
            print("Starting inference on new group:", p,g,t)
            directory="/work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/" + p + "/" + g + "/"+ t
            #print(directory)
            try:
                all_items = os.listdir(directory)
                #print("Total images, all angles:", len(all_items))
                #filter images for angle 08
                files08 = [os.path.join(directory, item) for item in all_items if item.endswith('08.jpg') and os.path.isfile(os.path.join(directory, item))]
                print("Images angle 08:", len(files08))
                prefix="results/" + p + "_" + g + "_" + t + "_jointModel"
                print("Save prefix:", prefix)
                inferenceOnData(files08, p, g, t, prefix)
                print("Finished group.")
            except Exception as e:
                print("~~ Not Found ~~")
                continue
# Out:
# Starting inference on new group: early_planting B73 no_treatment
# Images angle 08: 37
# Save prefix: early_planting_B73_no_treatment_jointModel
# No detections for image
# Progress: 0 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/155-6~0000000008.jpg
# No detections for image
# Progress: 1 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/155-6~0100000008.jpg
# No detections for image
# Progress: 2 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/155-6~0200000008.jpg
# No detections for image
# Progress: 3 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/155-6~0300000008.jpg
# No detections for image
# Progress: 4 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/155-6~0400000008.jpg
# Progress: 5 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/155-6~0500000008.jpg
# No detections for image
# Progress: 6 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/155-6~0600000008.jpg
# No detections for image
# Progress: 7 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0000000008.jpg
# No detections for image
# Progress: 8 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0100000008.jpg
# Progress: 9 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0200000008.jpg
# No detections for image
# Progress: 10 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0300000008.jpg
# No detections for image
# Progress: 11 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0400000008.jpg
# Progress: 12 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0500000008.jpg
# No detections for image
# Progress: 13 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0600000008.jpg
# Progress: 14 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-2~0700000008.jpg
# No detections for image
# Progress: 15 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0000000008.jpg
# No detections for image
# Progress: 16 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0100000008.jpg
# No detections for image
# Progress: 17 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0200000008.jpg
# Progress: 18 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0300000008.jpg
# No detections for image
# Progress: 19 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0400000008.jpg
# No detections for image
# Progress: 20 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0500000008.jpg
# No detections for image
# Progress: 21 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0600000008.jpg
# No detections for image
# Progress: 22 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-4~0700000008.jpg
# No detections for image
# Progress: 23 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-6~0000000008.jpg
# No detections for image
# Progress: 24 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-6~0100000008.jpg
# No detections for image
# Progress: 25 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-6~0200000008.jpg
# No detections for image
# Progress: 26 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-6~0300000008.jpg
# Progress: 27 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-6~0400000008.jpg
# Progress: 28 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0000000008.jpg
# No detections for image
# Progress: 29 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0100000008.jpg
# No detections for image
# Progress: 30 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0200000008.jpg
# No detections for image
# Progress: 31 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0300000008.jpg
# No detections for image
# Progress: 32 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0400000008.jpg
# No detections for image
# Progress: 33 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0500000008.jpg
# Progress: 34 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0600000008.jpg
# No detections for image
# Progress: 35 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0700000008.jpg
# No detections for image
# Progress: 36 / 37 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/B73/no_treatment/159-8~0800000008.jpg
# Finished group.
# Starting inference on new group: early_planting B73 defoliated
# ~~ Not Found ~~
# Starting inference on new group: early_planting gt1B73 no_treatment
# Images angle 08: 44
# Save prefix: early_planting_gt1B73_no_treatment_jointModel
# No detections for image
# Progress: 0 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0000000008.jpg
# Progress: 1 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0100000008.jpg
# No detections for image
# Progress: 2 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0200000008.jpg
# No detections for image
# Progress: 3 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0300000008.jpg
# No detections for image
# Progress: 4 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0400000008.jpg
# Progress: 5 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0500000008.jpg
# Progress: 6 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0600000008.jpg
# Progress: 7 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-2~0700000008.jpg
# No detections for image
# Progress: 8 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0000000008.jpg
# No detections for image
# Progress: 9 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0100000008.jpg
# No detections for image
# Progress: 10 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0200000008.jpg
# No detections for image
# Progress: 11 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0300000008.jpg
# No detections for image
# Progress: 12 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0400000008.jpg
# No detections for image
# Progress: 13 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0500000008.jpg
# No detections for image
# Progress: 14 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0600000008.jpg
# No detections for image
# Progress: 15 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-4~0700000008.jpg
# No detections for image
# Progress: 16 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0000000008.jpg
# Progress: 17 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0100000008.jpg
# No detections for image
# Progress: 18 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0200000008.jpg
# Progress: 19 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0300000008.jpg
# No detections for image
# Progress: 20 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0400000008.jpg
# No detections for image
# Progress: 21 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0500000008.jpg
# No detections for image
# Progress: 22 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0600000008.jpg
# No detections for image
# Progress: 23 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0700000008.jpg
# No detections for image
# Progress: 24 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0800000008.jpg
# No detections for image
# Progress: 25 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/153-8~0900000008.jpg
# Progress: 26 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0000000008.jpg
# No detections for image
# Progress: 27 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0100000008.jpg
# No detections for image
# Progress: 28 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0200000008.jpg
# Progress: 29 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0300000008.jpg
# Progress: 30 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0400000008.jpg
# Progress: 31 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0500000008.jpg
# No detections for image
# Progress: 32 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0600000008.jpg
# No detections for image
# Progress: 33 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0700000008.jpg
# No detections for image
# Progress: 34 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0800000008.jpg
# No detections for image
# Progress: 35 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-6~0900000008.jpg
# No detections for image
# Progress: 36 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0000000008.jpg
# No detections for image
# Progress: 37 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0100000008.jpg
# No detections for image
# Progress: 38 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0200000008.jpg
# No detections for image
# Progress: 39 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0300000008.jpg
# No detections for image
# Progress: 40 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0400000008.jpg
# No detections for image
# Progress: 41 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0500000008.jpg
# No detections for image
# Progress: 42 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0600000008.jpg
# No detections for image
# Progress: 43 / 44 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/no_treatment/157-8~0700000008.jpg
# Finished group.
# Starting inference on new group: early_planting gt1B73 defoliated
# Images angle 08: 11
# Save prefix: early_planting_gt1B73_defoliated_jointModel
# No detections for image
# Progress: 0 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-1~0000000008.jpg
# No detections for image
# Progress: 1 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-1~0100000008.jpg
# No detections for image
# Progress: 2 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-1~0200000008.jpg
# No detections for image
# Progress: 3 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-1~0300000008.jpg
# No detections for image
# Progress: 4 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-1~0400000008.jpg
# No detections for image
# Progress: 5 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-3~0000000008.jpg
# No detections for image
# Progress: 6 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-3~0100000008.jpg
# No detections for image
# Progress: 7 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-3~0200000008.jpg
# No detections for image
# Progress: 8 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-3~0300000008.jpg
# Progress: 9 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-3~0400000008.jpg
# Progress: 10 / 11 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/gt1B73/defoliated/153-3~0500000008.jpg
# Finished group.
# Starting inference on new group: early_planting ra3B73 no_treatment
# Images angle 08: 12
# Save prefix: early_planting_ra3B73_no_treatment_jointModel
# No detections for image
# Progress: 0 / 12 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/ra3B73/no_treatment/156-8~0000000008.jpg
# No detections for image
# Progress: 1 / 12 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/ra3B73/no_treatment/156-8~0100000008.jpg
# No detections for image
# Progress: 2 / 12 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/ra3B73/no_treatment/156-8~0200000008.jpg
# No detections for image
# Progress: 3 / 12 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/ra3B73/no_treatment/156-8~0300000008.jpg
# No detections for image
# Progress: 4 / 12 Running inference on /work/pi_mbartlett_umass_edu/AmberDeNeve/grass_carpel_ml_quantification_final/data/maize_21UM_data/early_planting/ra3B73/no_treatment